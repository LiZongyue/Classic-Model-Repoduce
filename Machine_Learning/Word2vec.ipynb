# %%
from __future__ import division, print_function, absolute_import

import collections
import os
import random
import urllib
import zipfile

import numpy as np
import tensorflow as tf

# %%
#Traning Parameters
learning_rate = 0.1
batch_size = 128
num_steps = 3000000
display_step = 10000
eval_step = 200000

#Evaluation Parameters
eval_words = ['five', 'of', 'going', 'hardware', 'american', 'britain']

#Word2Vec Parameters
embedding_size = 200 #Dimension of the embedding vector
max_vocabulary_size = 50000
min_occurrence = 10 #Remove words that do not appear at least n times
skip_window = 3 # How many words to consider (left and right of a center word)
num_skips = 2 # How many times to reuse an input to generate a label
num_sampled = 64 # Num of negative examples to sample

# %%
#Download a small chunk of Wikipedia articles collection
url = 'http://mattmahoney.net/dc/text8.zip'
data_path = 'text8.zip'
if not os.path.exists(data_path):
    print("Downloading the dataset... It takes time...")
    filename, _ = urllib.request.urlretrieve(url, data_path)
    print("Finished!")
#Unzip the dataset file,Text has already been processed
with zipfile.ZipFile(data_path) as f:
    text_words = f.read(f.namelist()[0]).lower().split()
# Out:
# Downloading the dataset... It takes time...
# Finished!

# %%
for i, word in enumerate(text_words):
    word = word.decode('UTF-8')
    text_words[i] = word

# %%
#Build the dictionary and replace rare words with UNK token
count = [("UNK", -1)]
#Retrieve the most common words
count.extend(collections.Counter(text_words).most_common(max_vocabulary_size - 1))
#Remove samples with less than min_occurence occurrences
for i in range(len(count) - 1, -1, -1):
    if count[i][1] < min_occurrence:
        count.pop(i)
    else:
        break # -1 order, once not <, don't need to retrieve any more.
#Computer the vovabulary size
vocabulary_size = len(count)
#Assign id to each word
word2id = dict()
for i, (word, _) in enumerate(count):
    word2id[word] = i

data = list()
unk_count = 0
#Retrieve word id, or assign it index 0 ("UNK") if not in dict
for word in text_words:
    index = word2id.get(word, 0)
    if index == 0:
        unk_count += 1
    data.append(index)
count[0] = ("UNK", unk_count)
id2word = dict(zip(word2id.values(), word2id.keys()))

print("Words count:\n", len(text_words))
print("Most Common Words:\n", count[:10])
print("Vocabulary size:\n", vocabulary_size)
print("Unique words:\n", len(set(text_words)))
# Out:
# Words count:
#  17005207
# Most Common Words:
#  [('UNK', 444176), ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764), ('in', 372201), ('a', 325873), ('to', 316376), ('zero', 264975), ('nine', 250430)]
# Vocabulary size:
#  47135
# Unique words:
#  253854

# %%
data_index = 0
# Generate training batch for the skip-gram model
def next_batch(batch_size, num_skips, skip_window):
    global data_index
    assert batch_size % num_skips == 0
    assert num_skips <= 2 * skip_window
    batch = np.ndarray(shape = (batch_size), dtype = np.int32)
    labels = np.ndarray(shape = (batch_size, 1), dtype = np.int32)
    #Windows' size
    span = 2 * skip_window + 1 # 1 represents the center word
    buffer = collections.deque(maxlen = span)
    if data_index + span > len(data):
        data_index = 0
    buffer.extend(data[data_index : data_index + span])
    data_index += span
    for i in range(batch_size // num_skips):
        context_word = [w for w in range(span) if w != skip_window]
        words_to_use = random.sample(context_word, num_skips)
        for j, context_word in enumerate(words_to_use):
            batch[i * num_skips + j] = buffer[skip_window]
            labels[i * num_skips + j, 0] = buffer[context_word]
        if data_index == len(data):
            buffer.extend(data[0 : span])
            data_index = span
        else:
            buffer.append(data[data_index])
            data_index += 1
    data_index = (data_index + len(data) - span) % len(data)
    return batch, labels

# %%
#Input
X = tf.placeholder(tf.int32, shape = [None])
Y = tf.placeholder(tf.int32, shape = [None, 1])

with tf.device('/cpu:0'):
    embedding = tf.Variable(tf.random_normal([vocabulary_size, embedding_size]))
    # Lookup the corresponding embedding vectors for each sample in X
    X_embed = tf.nn.embedding_lookup(embedding, X)
    # NCE Loss Variables
    nce_weights = tf.Variable(tf.random_normal([vocabulary_size, embedding_size]))
    nce_bias = tf.Variable(tf.random_normal([vocabulary_size]))
    
#Compute the average NCE loss for the batch
loss_op = tf.reduce_mean(
    tf.nn.nce_loss(weights = nce_weights,
                  biases = nce_bias,
                  labels = Y,
                  inputs = X_embed,
                  num_sampled = num_sampled,
                  num_classes = vocabulary_size))

#Optimizer 
optimizer = tf.train.GradientDescentOptimizer(learning_rate)
train_op = optimizer.minimize(loss_op)

#Evaluation
#Compute the cosine similarity between input data embedding and every embedding vectors
X_embed_norm = X_embed / tf.sqrt(tf.reduce_sum(tf.square(X_embed)))
embedding_norm = embedding / tf.sqrt(tf.reduce_sum(tf.square(embedding), 1, keepdims = True))
cosine_sim_op = tf.matmul(X_embed_norm, embedding_norm, transpose_b = True)

# %%
#Initialize the variables
init = tf.global_variables_initializer()

with tf.Session() as sess:
    
    sess.run(init)
    
    x_test = np.array([word2id[w] for w in eval_words])
    
    average_loss = 0
    for step in range(1, num_steps + 1):
        batch_x, batch_y = next_batch(batch_size, num_skips, skip_window)
        _, loss = sess.run([train_op, loss_op], feed_dict = {X : batch_x, Y : batch_y})
        average_loss += loss
        
        if step % display_step == 0 or step == 1:
            if step > 1:
                average_loss /= display_step
            print("Step " + str(step) + ", Average Loss = " + \
                 "{:4f}".format(average_loss))
            average_loss = 0
            
        #Evaluatiom
        if step % eval_step == 0 or step == 1:
            print("Evaluation...")
            sim = sess.run(cosine_sim_op, feed_dict = {X : x_test})
            for i in range(len(eval_words)):
                top_k = 8 # num of nearest neighbors
                nearest = (-sim[i, :]).argsort()[1:top_k + 1]
                log_str = '"%s" nearest neighbors:' % eval_words[i]
                for k in range(top_k):
                    log_str = '%s %s' % (log_str, id2word[nearest[k]])
                    print(log_str)
# Out:
# Step 1, Average Loss = 515.931152
# Evaluation...
# "five" nearest neighbors: paymaster
# "five" nearest neighbors: paymaster guarantee
# "five" nearest neighbors: paymaster guarantee sultanate
# "five" nearest neighbors: paymaster guarantee sultanate physik
# "five" nearest neighbors: paymaster guarantee sultanate physik despise
# "five" nearest neighbors: paymaster guarantee sultanate physik despise plug
# "five" nearest neighbors: paymaster guarantee sultanate physik despise plug awe
# "five" nearest neighbors: paymaster guarantee sultanate physik despise plug awe reconciled
# "of" nearest neighbors: tauris
# "of" nearest neighbors: tauris lleida
# "of" nearest neighbors: tauris lleida caryophyllales
# "of" nearest neighbors: tauris lleida caryophyllales wollheim
# "of" nearest neighbors: tauris lleida caryophyllales wollheim rear
# "of" nearest neighbors: tauris lleida caryophyllales wollheim rear billy
# "of" nearest neighbors: tauris lleida caryophyllales wollheim rear billy solubility
# "of" nearest neighbors: tauris lleida caryophyllales wollheim rear billy solubility dismayed
# "going" nearest neighbors: australasia
# "going" nearest neighbors: australasia subgenres
# "going" nearest neighbors: australasia subgenres shopping
# "going" nearest neighbors: australasia subgenres shopping imperatives
# "going" nearest neighbors: australasia subgenres shopping imperatives soil
# "going" nearest neighbors: australasia subgenres shopping imperatives soil pain
# "going" nearest neighbors: australasia subgenres shopping imperatives soil pain squire
# "going" nearest neighbors: australasia subgenres shopping imperatives soil pain squire invertebrate
# "hardware" nearest neighbors: uriah
# "hardware" nearest neighbors: uriah fitted
# "hardware" nearest neighbors: uriah fitted veda
# "hardware" nearest neighbors: uriah fitted veda frg
# "hardware" nearest neighbors: uriah fitted veda frg ox
# "hardware" nearest neighbors: uriah fitted veda frg ox reincorporated
# "hardware" nearest neighbors: uriah fitted veda frg ox reincorporated bukharin
# "hardware" nearest neighbors: uriah fitted veda frg ox reincorporated bukharin insoluble
# "american" nearest neighbors: crete
# "american" nearest neighbors: crete likewise
# "american" nearest neighbors: crete likewise counsel
# "american" nearest neighbors: crete likewise counsel visa
# "american" nearest neighbors: crete likewise counsel visa anticipated
# "american" nearest neighbors: crete likewise counsel visa anticipated undermine
# "american" nearest neighbors: crete likewise counsel visa anticipated undermine gallon
# "american" nearest neighbors: crete likewise counsel visa anticipated undermine gallon licensee
# "britain" nearest neighbors: preface
# "britain" nearest neighbors: preface selena
# "britain" nearest neighbors: preface selena magi
# "britain" nearest neighbors: preface selena magi exhibits
# "britain" nearest neighbors: preface selena magi exhibits memorization
# "britain" nearest neighbors: preface selena magi exhibits memorization gypsy
# "britain" nearest neighbors: preface selena magi exhibits memorization gypsy comfortably
# "britain" nearest neighbors: preface selena magi exhibits memorization gypsy comfortably exemplary
# Step 10000, Average Loss = 198.463577
# Step 20000, Average Loss = 93.734679
# Step 30000, Average Loss = 65.176587
# Step 40000, Average Loss = 51.031558
# Step 50000, Average Loss = 41.398939
# Step 60000, Average Loss = 36.383402
# Step 70000, Average Loss = 31.909365
# Step 80000, Average Loss = 29.605399
# Step 90000, Average Loss = 27.463269
# Step 100000, Average Loss = 24.734976
# Step 110000, Average Loss = 23.329925
# Step 120000, Average Loss = 21.099756
# Step 130000, Average Loss = 20.404481
# Step 140000, Average Loss = 19.282410
# Step 150000, Average Loss = 18.697970
# Step 160000, Average Loss = 17.695726
# Step 170000, Average Loss = 16.891428
# Step 180000, Average Loss = 16.316305
# Step 190000, Average Loss = 15.352902
# Step 200000, Average Loss = 14.554234
# Evaluation...
# "five" nearest neighbors: four
# "five" nearest neighbors: four three
# "five" nearest neighbors: four three seven
# "five" nearest neighbors: four three seven six
# "five" nearest neighbors: four three seven six eight
# "five" nearest neighbors: four three seven six eight two
# "five" nearest neighbors: four three seven six eight two nine
# "five" nearest neighbors: four three seven six eight two nine zero
# "of" nearest neighbors: the
# "of" nearest neighbors: the with
# "of" nearest neighbors: the with when
# "of" nearest neighbors: the with when a
# "of" nearest neighbors: the with when a and
# "of" nearest neighbors: the with when a and is
# "of" nearest neighbors: the with when a and is on
# "of" nearest neighbors: the with when a and is on from
# "going" nearest neighbors: could
# "going" nearest neighbors: could or
# "going" nearest neighbors: could or who
# "going" nearest neighbors: could or who new
# "going" nearest neighbors: could or who new such
# "going" nearest neighbors: could or who new such on
# "going" nearest neighbors: could or who new such on was
# "going" nearest neighbors: could or who new such on was UNK
# "hardware" nearest neighbors: september
# "hardware" nearest neighbors: september modern
# "hardware" nearest neighbors: september modern plane
# "hardware" nearest neighbors: september modern plane early
# "hardware" nearest neighbors: september modern plane early science
# "hardware" nearest neighbors: september modern plane early science are
# "hardware" nearest neighbors: september modern plane early science are and
# "hardware" nearest neighbors: september modern plane early science are and called
# "american" nearest neighbors: UNK
# "american" nearest neighbors: UNK and
# "american" nearest neighbors: UNK and in
# "american" nearest neighbors: UNK and in when
# "american" nearest neighbors: UNK and in when with
# "american" nearest neighbors: UNK and in when with from
# "american" nearest neighbors: UNK and in when with from after
# "american" nearest neighbors: UNK and in when with from after an
# "britain" nearest neighbors: and
# "britain" nearest neighbors: and city
# "britain" nearest neighbors: and city so
# "britain" nearest neighbors: and city so or
# "britain" nearest neighbors: and city so or who
# "britain" nearest neighbors: and city so or who while
# "britain" nearest neighbors: and city so or who while have
# "britain" nearest neighbors: and city so or who while have most
# Step 210000, Average Loss = 14.442666
# Step 220000, Average Loss = 15.003963
# Step 230000, Average Loss = 13.598928
# Step 240000, Average Loss = 14.112307
# Step 250000, Average Loss = 12.805682
# Step 260000, Average Loss = 12.855580
# Step 270000, Average Loss = 12.677518
# Step 280000, Average Loss = 11.776838
# Step 290000, Average Loss = 11.327693
# Step 300000, Average Loss = 11.456436
# Step 310000, Average Loss = 10.832146
# Step 320000, Average Loss = 10.862991
# Step 330000, Average Loss = 10.542129
# Step 340000, Average Loss = 10.481086
# Step 350000, Average Loss = 10.701200
# Step 360000, Average Loss = 10.301232
# Step 370000, Average Loss = 10.137492
# Step 380000, Average Loss = 10.064986
# Step 390000, Average Loss = 9.748808
# Step 400000, Average Loss = 9.680352
# Evaluation...
# "five" nearest neighbors: four
# "five" nearest neighbors: four three
# "five" nearest neighbors: four three six
# "five" nearest neighbors: four three six two
# "five" nearest neighbors: four three six two eight
# "five" nearest neighbors: four three six two eight seven
# "five" nearest neighbors: four three six two eight seven one
# "five" nearest neighbors: four three six two eight seven one zero
# "of" nearest neighbors: the
# "of" nearest neighbors: the and
# "of" nearest neighbors: the and with
# "of" nearest neighbors: the and with or
# "of" nearest neighbors: the and with or a
# "of" nearest neighbors: the and with or a including
# "of" nearest neighbors: the and with or a including for
# "of" nearest neighbors: the and with or a including for while
# "going" nearest neighbors: general
# "going" nearest neighbors: general n
# "going" nearest neighbors: general n UNK
# "going" nearest neighbors: general n UNK new
# "going" nearest neighbors: general n UNK new him
# "going" nearest neighbors: general n UNK new him her
# "going" nearest neighbors: general n UNK new him her university
# "going" nearest neighbors: general n UNK new him her university on
# "hardware" nearest neighbors: modern
# "hardware" nearest neighbors: modern de
# "hardware" nearest neighbors: modern de or
# "hardware" nearest neighbors: modern de or called
# "hardware" nearest neighbors: modern de or called only
# "hardware" nearest neighbors: modern de or called only well
# "hardware" nearest neighbors: modern de or called only well their
# "hardware" nearest neighbors: modern de or called only well their such
# "american" nearest neighbors: s
# "american" nearest neighbors: s from
# "american" nearest neighbors: s from english
# "american" nearest neighbors: s from english and
# "american" nearest neighbors: s from english and in
# "american" nearest neighbors: s from english and in including
# "american" nearest neighbors: s from english and in including when
# "american" nearest neighbors: s from english and in including when on
# "britain" nearest neighbors: city
# "britain" nearest neighbors: city most
# "britain" nearest neighbors: city most also
# "britain" nearest neighbors: city most also modern
# "britain" nearest neighbors: city most also modern these
# "britain" nearest neighbors: city most also modern these name
# "britain" nearest neighbors: city most also modern these name some
# "britain" nearest neighbors: city most also modern these name some by
# Step 410000, Average Loss = 9.815817
# Step 420000, Average Loss = 9.278574
# Step 430000, Average Loss = 9.504482
# Step 440000, Average Loss = 9.210628
# Step 450000, Average Loss = 9.262757
# Step 460000, Average Loss = 8.928328
# Step 470000, Average Loss = 8.622349
# Step 480000, Average Loss = 8.793839
# Step 490000, Average Loss = 9.031920
# Step 500000, Average Loss = 8.872289
# Step 510000, Average Loss = 8.563657
# Step 520000, Average Loss = 8.632819
# Step 530000, Average Loss = 8.650152
# Step 540000, Average Loss = 8.376483
# Step 550000, Average Loss = 8.212923
# Step 560000, Average Loss = 8.200018
# Step 570000, Average Loss = 8.135792
# Step 580000, Average Loss = 7.999315
# Step 590000, Average Loss = 8.090540
# Step 600000, Average Loss = 7.854766
# Evaluation...
# "five" nearest neighbors: six
# "five" nearest neighbors: six four
# "five" nearest neighbors: six four three
# "five" nearest neighbors: six four three two
# "five" nearest neighbors: six four three two seven
# "five" nearest neighbors: six four three two seven eight
# "five" nearest neighbors: six four three two seven eight one
# "five" nearest neighbors: six four three two seven eight one zero
# "of" nearest neighbors: and
# "of" nearest neighbors: and the
# "of" nearest neighbors: and the including
# "of" nearest neighbors: and the including a
# "of" nearest neighbors: and the including a with
# "of" nearest neighbors: and the including a with its
# "of" nearest neighbors: and the including a with its for
# "of" nearest neighbors: and the including a with its for in
# "going" nearest neighbors: UNK
# "going" nearest neighbors: UNK with
# "going" nearest neighbors: UNK with general
# "going" nearest neighbors: UNK with general him
# "going" nearest neighbors: UNK with general him he
# "going" nearest neighbors: UNK with general him he her
# "going" nearest neighbors: UNK with general him he her based
# "going" nearest neighbors: UNK with general him he her based and
# "hardware" nearest neighbors: or
# "hardware" nearest neighbors: or an
# "hardware" nearest neighbors: or an including
# "hardware" nearest neighbors: or an including still
# "hardware" nearest neighbors: or an including still modern
# "hardware" nearest neighbors: or an including still modern his
# "hardware" nearest neighbors: or an including still modern his system
# "hardware" nearest neighbors: or an including still modern his system a
# "american" nearest neighbors: english
# "american" nearest neighbors: english french
# "american" nearest neighbors: english french german
# "american" nearest neighbors: english french german in
# "american" nearest neighbors: english french german in s
# "american" nearest neighbors: english french german in s and
# "american" nearest neighbors: english french german in s and including
# "american" nearest neighbors: english french german in s and including during
# "britain" nearest neighbors: including
# "britain" nearest neighbors: including most
# "britain" nearest neighbors: including most great
# "britain" nearest neighbors: including most great by
# "britain" nearest neighbors: including most great by long
# "britain" nearest neighbors: including most great by long her
# "britain" nearest neighbors: including most great by long her where
# "britain" nearest neighbors: including most great by long her where were
# Step 610000, Average Loss = 7.983564
# Step 620000, Average Loss = 8.075144
# Step 630000, Average Loss = 7.848580
# Step 640000, Average Loss = 7.904215
# Step 650000, Average Loss = 7.683046
# Step 660000, Average Loss = 7.734607
# Step 670000, Average Loss = 7.606461
# Step 680000, Average Loss = 7.800386
# Step 690000, Average Loss = 7.570329
# Step 700000, Average Loss = 7.570104
# Step 710000, Average Loss = 7.499669
# Step 720000, Average Loss = 7.452706
# Step 730000, Average Loss = 7.339566
# Step 740000, Average Loss = 7.141834
# Step 750000, Average Loss = 7.478724
# Step 760000, Average Loss = 7.277418
# Step 770000, Average Loss = 7.485615
# Step 780000, Average Loss = 7.173939
# Step 790000, Average Loss = 7.260087
# Step 800000, Average Loss = 7.315433
# Evaluation...
# "five" nearest neighbors: four
# "five" nearest neighbors: four six
# "five" nearest neighbors: four six three
# "five" nearest neighbors: four six three two
# "five" nearest neighbors: four six three two seven
# "five" nearest neighbors: four six three two seven eight
# "five" nearest neighbors: four six three two seven eight one
# "five" nearest neighbors: four six three two seven eight one zero
# "of" nearest neighbors: and
# "of" nearest neighbors: and the
# "of" nearest neighbors: and the from
# "of" nearest neighbors: and the from including
# "of" nearest neighbors: and the from including in
# "of" nearest neighbors: and the from including in its
# "of" nearest neighbors: and the from including in its with
# "of" nearest neighbors: and the from including in its with first
# "going" nearest neighbors: without
# "going" nearest neighbors: without called
# "going" nearest neighbors: without called music
# "going" nearest neighbors: without called music based
# "going" nearest neighbors: without called music based who
# "going" nearest neighbors: without called music based who about
# "going" nearest neighbors: without called music based who about them
# "going" nearest neighbors: without called music based who about them i
# "hardware" nearest neighbors: free
# "hardware" nearest neighbors: free other
# "hardware" nearest neighbors: free other include
# "hardware" nearest neighbors: free other include produced
# "hardware" nearest neighbors: free other include produced computer
# "hardware" nearest neighbors: free other include produced computer an
# "hardware" nearest neighbors: free other include produced computer an however
# "hardware" nearest neighbors: free other include produced computer an however are
# "american" nearest neighbors: b
# "american" nearest neighbors: b born
# "american" nearest neighbors: b born english
# "american" nearest neighbors: b born english german
# "american" nearest neighbors: b born english german d
# "american" nearest neighbors: b born english german d british
# "american" nearest neighbors: b born english german d british french
# "american" nearest neighbors: b born english german d british french john
# "britain" nearest neighbors: thus
# "britain" nearest neighbors: thus where
# "britain" nearest neighbors: thus where great
# "britain" nearest neighbors: thus where great were
# "britain" nearest neighbors: thus where great were high
# "britain" nearest neighbors: thus where great were high most
# "britain" nearest neighbors: thus where great were high most other
# "britain" nearest neighbors: thus where great were high most other between
# Step 810000, Average Loss = 7.131522
# Step 820000, Average Loss = 7.037789
# Step 830000, Average Loss = 7.184825
# Step 840000, Average Loss = 7.014024
# Step 850000, Average Loss = 7.004256
# Step 860000, Average Loss = 7.039812
# Step 870000, Average Loss = 6.946792
# Step 880000, Average Loss = 7.089018
# Step 890000, Average Loss = 7.027358
# Step 900000, Average Loss = 6.972023
# Step 910000, Average Loss = 7.019315
# Step 920000, Average Loss = 6.828882
# Step 930000, Average Loss = 6.887291
# Step 940000, Average Loss = 6.956717
# Step 950000, Average Loss = 6.746733
# Step 960000, Average Loss = 6.923873
# Step 970000, Average Loss = 6.737039
# Step 980000, Average Loss = 6.865464
# Step 990000, Average Loss = 6.666637
# Step 1000000, Average Loss = 6.538637
# Evaluation...
# "five" nearest neighbors: four
# "five" nearest neighbors: four six
# "five" nearest neighbors: four six three
# "five" nearest neighbors: four six three seven
# "five" nearest neighbors: four six three seven eight
# "five" nearest neighbors: four six three seven eight nine
# "five" nearest neighbors: four six three seven eight nine two
# "five" nearest neighbors: four six three seven eight nine two zero
# "of" nearest neighbors: became
# "of" nearest neighbors: became first
# "of" nearest neighbors: became first the
# "of" nearest neighbors: became first the including
# "of" nearest neighbors: became first the including from
# "of" nearest neighbors: became first the including from following
# "of" nearest neighbors: became first the including from following second
# "of" nearest neighbors: became first the including from following second and
# "going" nearest neighbors: he
# "going" nearest neighbors: he without
# "going" nearest neighbors: he without her
# "going" nearest neighbors: he without her work
# "going" nearest neighbors: he without her work within
# "going" nearest neighbors: he without her work within different
# "going" nearest neighbors: he without her work within different or
# "going" nearest neighbors: he without her work within different or who
# "hardware" nearest neighbors: produced
# "hardware" nearest neighbors: produced free
# "hardware" nearest neighbors: produced free software
# "hardware" nearest neighbors: produced free software these
# "hardware" nearest neighbors: produced free software these with
# "hardware" nearest neighbors: produced free software these with similar
# "hardware" nearest neighbors: produced free software these with similar such
# "hardware" nearest neighbors: produced free software these with similar such at
# "american" nearest neighbors: d
# "american" nearest neighbors: d b
# "american" nearest neighbors: d b born
# "american" nearest neighbors: d b born UNK
# "american" nearest neighbors: d b born UNK john
# "american" nearest neighbors: d b born UNK john nine
# "american" nearest neighbors: d b born UNK john nine german
# "american" nearest neighbors: d b born UNK john nine german french
# "britain" nearest neighbors: great
# "britain" nearest neighbors: great include
# "britain" nearest neighbors: great include between
# "britain" nearest neighbors: great include between with
# "britain" nearest neighbors: great include between with including
# "britain" nearest neighbors: great include between with including other
# "britain" nearest neighbors: great include between with including other and
# "britain" nearest neighbors: great include between with including other and high
# Step 1010000, Average Loss = 6.619600
# Step 1020000, Average Loss = 6.830632
# Step 1030000, Average Loss = 6.686428
# Step 1040000, Average Loss = 6.675690
# Step 1050000, Average Loss = 6.633317
# Step 1060000, Average Loss = 6.666533
# Step 1070000, Average Loss = 6.675185
# Step 1080000, Average Loss = 6.529944
# Step 1090000, Average Loss = 6.555566
# Step 1100000, Average Loss = 6.631552
# Step 1110000, Average Loss = 6.471942
# Step 1120000, Average Loss = 6.569354
# Step 1130000, Average Loss = 6.462279
# Step 1140000, Average Loss = 6.543951
# Step 1150000, Average Loss = 6.644977
# Step 1160000, Average Loss = 6.501319
# Step 1170000, Average Loss = 6.539650
# Step 1180000, Average Loss = 6.442169
# Step 1190000, Average Loss = 6.480172
# Step 1200000, Average Loss = 6.412401
# Evaluation...
# "five" nearest neighbors: four
# "five" nearest neighbors: four six
# "five" nearest neighbors: four six three
# "five" nearest neighbors: four six three seven
# "five" nearest neighbors: four six three seven eight
# "five" nearest neighbors: four six three seven eight two
# "five" nearest neighbors: four six three seven eight two nine
# "five" nearest neighbors: four six three seven eight two nine one
# "of" nearest neighbors: the
# "of" nearest neighbors: the including
# "of" nearest neighbors: the including and
# "of" nearest neighbors: the including and in
# "of" nearest neighbors: the including and in first
# "of" nearest neighbors: the including and in first from
# "of" nearest neighbors: the including and in first from following
# "of" nearest neighbors: the including and in first from following became
# "going" nearest neighbors: without
# "going" nearest neighbors: without which
# "going" nearest neighbors: without which general
# "going" nearest neighbors: without which general within
# "going" nearest neighbors: without which general within back
# "going" nearest neighbors: without which general within back before
# "going" nearest neighbors: without which general within back before by
# "going" nearest neighbors: without which general within back before by then
# "hardware" nearest neighbors: produced
# "hardware" nearest neighbors: produced free
# "hardware" nearest neighbors: produced free popular
# "hardware" nearest neighbors: produced free popular for
# "hardware" nearest neighbors: produced free popular for software
# "hardware" nearest neighbors: produced free popular for software religious
# "hardware" nearest neighbors: produced free popular for software religious areas
# "hardware" nearest neighbors: produced free popular for software religious areas energy
# "american" nearest neighbors: born
# "american" nearest neighbors: born d
# "american" nearest neighbors: born d b
# "american" nearest neighbors: born d b german
# "american" nearest neighbors: born d b german UNK
# "american" nearest neighbors: born d b german UNK english
# "american" nearest neighbors: born d b german UNK english john
# "american" nearest neighbors: born d b german UNK english john british
# "britain" nearest neighbors: great
# "britain" nearest neighbors: great between
# "britain" nearest neighbors: great between led
# "britain" nearest neighbors: great between led with
# "britain" nearest neighbors: great between led with further
# "britain" nearest neighbors: great between led with further country
# "britain" nearest neighbors: great between led with further country including
# "britain" nearest neighbors: great between led with further country including along
# Step 1210000, Average Loss = 6.538840
# Step 1220000, Average Loss = 6.376376
# Step 1230000, Average Loss = 6.446418
# Step 1240000, Average Loss = 6.413276
# Step 1250000, Average Loss = 6.372511
# Step 1260000, Average Loss = 6.333629
# Step 1270000, Average Loss = 6.092887
# Step 1280000, Average Loss = 6.383945
# Step 1290000, Average Loss = 6.319375
# Step 1300000, Average Loss = 6.469080
# Step 1310000, Average Loss = 6.245210
# Step 1320000, Average Loss = 6.302574
# Step 1330000, Average Loss = 6.367233
# Step 1340000, Average Loss = 6.261571
# Step 1350000, Average Loss = 6.221137
# Step 1360000, Average Loss = 6.281536
# Step 1370000, Average Loss = 6.238257
# Step 1380000, Average Loss = 6.244769
# Step 1390000, Average Loss = 6.274699
# Step 1400000, Average Loss = 6.215566
# Evaluation...
# "five" nearest neighbors: four
# "five" nearest neighbors: four three
# "five" nearest neighbors: four three six
# "five" nearest neighbors: four three six two
# "five" nearest neighbors: four three six two seven
# "five" nearest neighbors: four three six two seven eight
# "five" nearest neighbors: four three six two seven eight one
# "five" nearest neighbors: four three six two seven eight one zero
# "of" nearest neighbors: the
# "of" nearest neighbors: the including
# "of" nearest neighbors: the including and
# "of" nearest neighbors: the including and in
# "of" nearest neighbors: the including and in its
# "of" nearest neighbors: the including and in its part
# "of" nearest neighbors: the including and in its part within
# "of" nearest neighbors: the including and in its part within especially
# "going" nearest neighbors: but
# "going" nearest neighbors: but them
# "going" nearest neighbors: but them just
# "going" nearest neighbors: but them just only
# "going" nearest neighbors: but them just only without
# "going" nearest neighbors: but them just only without with
# "going" nearest neighbors: but them just only without with however
# "going" nearest neighbors: but them just only without with however before
# "hardware" nearest neighbors: produced
# "hardware" nearest neighbors: produced energy
# "hardware" nearest neighbors: produced energy areas
# "hardware" nearest neighbors: produced energy areas these
# "hardware" nearest neighbors: produced energy areas these a
# "hardware" nearest neighbors: produced energy areas these a free
# "hardware" nearest neighbors: produced energy areas these a free using
# "hardware" nearest neighbors: produced energy areas these a free using for
# "american" nearest neighbors: german
# "american" nearest neighbors: german english
# "american" nearest neighbors: german english french
# "american" nearest neighbors: german english french born
# "american" nearest neighbors: german english french born s
# "american" nearest neighbors: german english french born s british
# "american" nearest neighbors: german english french born s british john
# "american" nearest neighbors: german english french born s british john former
# "britain" nearest neighbors: including
# "britain" nearest neighbors: including great
# "britain" nearest neighbors: including great led
# "britain" nearest neighbors: including great led between
# "britain" nearest neighbors: including great led between and
# "britain" nearest neighbors: including great led between and were
# "britain" nearest neighbors: including great led between and were people
# "britain" nearest neighbors: including great led between and were people further
# Step 1410000, Average Loss = 6.274615
# Step 1420000, Average Loss = 6.294155
# Step 1430000, Average Loss = 6.252673
# Step 1440000, Average Loss = 6.277716
# Step 1450000, Average Loss = 6.152089
# Step 1460000, Average Loss = 6.185825
# Step 1470000, Average Loss = 6.216873
# Step 1480000, Average Loss = 6.136613
# Step 1490000, Average Loss = 6.239929
# Step 1500000, Average Loss = 6.143905
# Step 1510000, Average Loss = 6.190698
# Step 1520000, Average Loss = 6.066770
# Step 1530000, Average Loss = 5.953897
# Step 1540000, Average Loss = 6.024277
# Step 1550000, Average Loss = 6.206440
# Step 1560000, Average Loss = 6.085006
# Step 1570000, Average Loss = 6.155109
# Step 1580000, Average Loss = 6.000988
# Step 1590000, Average Loss = 6.104100
# Step 1600000, Average Loss = 6.138757
# Evaluation...
# "five" nearest neighbors: four
# "five" nearest neighbors: four three
# "five" nearest neighbors: four three six
# "five" nearest neighbors: four three six two
# "five" nearest neighbors: four three six two seven
# "five" nearest neighbors: four three six two seven eight
# "five" nearest neighbors: four three six two seven eight zero
# "five" nearest neighbors: four three six two seven eight zero one
# "of" nearest neighbors: the
# "of" nearest neighbors: the and
# "of" nearest neighbors: the and original
# "of" nearest neighbors: the and original including
# "of" nearest neighbors: the and original including with
# "of" nearest neighbors: the and original including with from
# "of" nearest neighbors: the and original including with from in
# "of" nearest neighbors: the and original including with from in its
# "going" nearest neighbors: without
# "going" nearest neighbors: without just
# "going" nearest neighbors: without just order
# "going" nearest neighbors: without just order which
# "going" nearest neighbors: without just order which how
# "going" nearest neighbors: without just order which how then
# "going" nearest neighbors: without just order which how then him
# "going" nearest neighbors: without just order which how then him them
# "hardware" nearest neighbors: built
# "hardware" nearest neighbors: built using
# "hardware" nearest neighbors: built using energy
# "hardware" nearest neighbors: built using energy produced
# "hardware" nearest neighbors: built using energy produced computer
# "hardware" nearest neighbors: built using energy produced computer an
# "hardware" nearest neighbors: built using energy produced computer an higher
# "hardware" nearest neighbors: built using energy produced computer an higher includes
# "american" nearest neighbors: born
# "american" nearest neighbors: born english
# "american" nearest neighbors: born english german
# "american" nearest neighbors: born english german british
# "american" nearest neighbors: born english german british french
# "american" nearest neighbors: born english german british french b
# "american" nearest neighbors: born english german british french b d
# "american" nearest neighbors: born english german british french b d robert
# "britain" nearest neighbors: great
# "britain" nearest neighbors: great between
# "britain" nearest neighbors: great between northern
# "britain" nearest neighbors: great between northern with
# "britain" nearest neighbors: great between northern with country
# "britain" nearest neighbors: great between northern with country led
# "britain" nearest neighbors: great between northern with country led including
# "britain" nearest neighbors: great between northern with country led including society
# Step 1610000, Average Loss = 6.054028
# Step 1620000, Average Loss = 6.010270
# Step 1630000, Average Loss = 6.105283
# Step 1640000, Average Loss = 6.018218
# Step 1650000, Average Loss = 6.082092
# Step 1660000, Average Loss = 5.990065
# Step 1670000, Average Loss = 6.068949
# Step 1680000, Average Loss = 6.131071
# Step 1690000, Average Loss = 6.084009
# Step 1700000, Average Loss = 6.049506
# Step 1710000, Average Loss = 6.004802
# Step 1720000, Average Loss = 6.032802
# Step 1730000, Average Loss = 5.973735
# Step 1740000, Average Loss = 6.088704
# Step 1750000, Average Loss = 5.945672
# Step 1760000, Average Loss = 6.033279
# Step 1770000, Average Loss = 5.984999
# Step 1780000, Average Loss = 5.979765
# Step 1790000, Average Loss = 5.941413
# Step 1800000, Average Loss = 5.706453
# Evaluation...
# "five" nearest neighbors: four
# "five" nearest neighbors: four six
# "five" nearest neighbors: four six three
# "five" nearest neighbors: four six three seven
# "five" nearest neighbors: four six three seven eight
# "five" nearest neighbors: four six three seven eight nine
# "five" nearest neighbors: four six three seven eight nine two
# "five" nearest neighbors: four six three seven eight nine two zero
# "of" nearest neighbors: the
# "of" nearest neighbors: the first
# "of" nearest neighbors: the first became
# "of" nearest neighbors: the first became in
# "of" nearest neighbors: the first became in and
# "of" nearest neighbors: the first became in and following
# "of" nearest neighbors: the first became in and following from
# "of" nearest neighbors: the first became in and following from at
# "going" nearest neighbors: without
# "going" nearest neighbors: without having
# "going" nearest neighbors: without having how
# "going" nearest neighbors: without having how just
# "going" nearest neighbors: without having how just to
# "going" nearest neighbors: without having how just to must
# "going" nearest neighbors: without having how just to must them
# "going" nearest neighbors: without having how just to must them while
# "hardware" nearest neighbors: energy
# "hardware" nearest neighbors: energy built
# "hardware" nearest neighbors: energy built produced
# "hardware" nearest neighbors: energy built produced includes
# "hardware" nearest neighbors: energy built produced includes higher
# "hardware" nearest neighbors: energy built produced includes higher software
# "hardware" nearest neighbors: energy built produced includes higher software free
# "hardware" nearest neighbors: energy built produced includes higher software free computer
# "american" nearest neighbors: d
# "american" nearest neighbors: d b
# "american" nearest neighbors: d b born
# "american" nearest neighbors: d b born actor
# "american" nearest neighbors: d b born actor robert
# "american" nearest neighbors: d b born actor robert UNK
# "american" nearest neighbors: d b born actor robert UNK william
# "american" nearest neighbors: d b born actor robert UNK william david
# "britain" nearest neighbors: great
# "britain" nearest neighbors: great northern
# "britain" nearest neighbors: great northern country
# "britain" nearest neighbors: great northern country with
# "britain" nearest neighbors: great northern country with from
# "britain" nearest neighbors: great northern country with from along
# "britain" nearest neighbors: great northern country with from along england
# "britain" nearest neighbors: great northern country with from along england led
# Step 1810000, Average Loss = 5.955745
# Step 1820000, Average Loss = 5.957315
# Step 1830000, Average Loss = 6.032342
# Step 1840000, Average Loss = 5.878431
# Step 1850000, Average Loss = 5.930851
# Step 1860000, Average Loss = 5.966666
# Step 1870000, Average Loss = 5.903945
# Step 1880000, Average Loss = 5.885401
# Step 1890000, Average Loss = 5.914600
# Step 1900000, Average Loss = 5.908810
# Step 1910000, Average Loss = 5.900452
# Step 1920000, Average Loss = 5.936743
# Step 1930000, Average Loss = 5.883854
# Step 1940000, Average Loss = 5.926335
# Step 1950000, Average Loss = 5.990043
# Step 1960000, Average Loss = 5.920156
# Step 1970000, Average Loss = 5.912613
# Step 1980000, Average Loss = 5.860957
# Step 1990000, Average Loss = 5.898277
# Step 2000000, Average Loss = 5.852531
# Evaluation...
# "five" nearest neighbors: three
# "five" nearest neighbors: three six
# "five" nearest neighbors: three six four
# "five" nearest neighbors: three six four seven
# "five" nearest neighbors: three six four seven eight
# "five" nearest neighbors: three six four seven eight two
# "five" nearest neighbors: three six four seven eight two nine
# "five" nearest neighbors: three six four seven eight two nine zero
# "of" nearest neighbors: including
# "of" nearest neighbors: including its
# "of" nearest neighbors: including its the
# "of" nearest neighbors: including its the from
# "of" nearest neighbors: including its the from for
# "of" nearest neighbors: including its the from for and
# "of" nearest neighbors: including its the from for and while
# "of" nearest neighbors: including its the from for and while modern
# "going" nearest neighbors: eventually
# "going" nearest neighbors: eventually just
# "going" nearest neighbors: eventually just them
# "going" nearest neighbors: eventually just them off
# "going" nearest neighbors: eventually just them off but
# "going" nearest neighbors: eventually just them off but without
# "going" nearest neighbors: eventually just them off but without having
# "going" nearest neighbors: eventually just them off but without having when
# "hardware" nearest neighbors: software
# "hardware" nearest neighbors: software free
# "hardware" nearest neighbors: software free building
# "hardware" nearest neighbors: software free building program
# "hardware" nearest neighbors: software free building program using
# "hardware" nearest neighbors: software free building program using certain
# "hardware" nearest neighbors: software free building program using certain an
# "hardware" nearest neighbors: software free building program using certain an higher
# "american" nearest neighbors: born
# "american" nearest neighbors: born actor
# "american" nearest neighbors: born actor robert
# "american" nearest neighbors: born actor robert d
# "american" nearest neighbors: born actor robert d b
# "american" nearest neighbors: born actor robert d b william
# "american" nearest neighbors: born actor robert d b william john
# "american" nearest neighbors: born actor robert d b william john singer
# "britain" nearest neighbors: northern
# "britain" nearest neighbors: northern great
# "britain" nearest neighbors: northern great england
# "britain" nearest neighbors: northern great england led
# "britain" nearest neighbors: northern great england led against
# "britain" nearest neighbors: northern great england led against country
# "britain" nearest neighbors: northern great england led against country government
# "britain" nearest neighbors: northern great england led against country government along
# Step 2010000, Average Loss = 5.912154
# Step 2020000, Average Loss = 5.872929
# Step 2030000, Average Loss = 5.891014
# Step 2040000, Average Loss = 5.869043
# Step 2050000, Average Loss = 5.829942
# Step 2060000, Average Loss = 5.708244
# Step 2070000, Average Loss = 5.682860
# Step 2080000, Average Loss = 5.905600
# Step 2090000, Average Loss = 5.794695
# Step 2100000, Average Loss = 5.913790
# Step 2110000, Average Loss = 5.698936
# Step 2120000, Average Loss = 5.806328
# Step 2130000, Average Loss = 5.871627
# Step 2140000, Average Loss = 5.806157
# Step 2150000, Average Loss = 5.744243
# Step 2160000, Average Loss = 5.837923
# Step 2170000, Average Loss = 5.775075
# Step 2180000, Average Loss = 5.825309
# Step 2190000, Average Loss = 5.782572
# Step 2200000, Average Loss = 5.789452
# Evaluation...
# "five" nearest neighbors: three
# "five" nearest neighbors: three four
# "five" nearest neighbors: three four six
# "five" nearest neighbors: three four six two
# "five" nearest neighbors: three four six two eight
# "five" nearest neighbors: three four six two eight seven
# "five" nearest neighbors: three four six two eight seven zero
# "five" nearest neighbors: three four six two eight seven zero one
# "of" nearest neighbors: including
# "of" nearest neighbors: including its
# "of" nearest neighbors: including its in
# "of" nearest neighbors: including its in the
# "of" nearest neighbors: including its in the and
# "of" nearest neighbors: including its in the and from
# "of" nearest neighbors: including its in the and from especially
# "of" nearest neighbors: including its in the and from especially on
# "going" nearest neighbors: eventually
# "going" nearest neighbors: eventually without
# "going" nearest neighbors: eventually without with
# "going" nearest neighbors: eventually without with then
# "going" nearest neighbors: eventually without with then just
# "going" nearest neighbors: eventually without with then just how
# "going" nearest neighbors: eventually without with then just how back
# "going" nearest neighbors: eventually without with then just how back off
# "hardware" nearest neighbors: software
# "hardware" nearest neighbors: software free
# "hardware" nearest neighbors: software free information
# "hardware" nearest neighbors: software free information building
# "hardware" nearest neighbors: software free information building using
# "hardware" nearest neighbors: software free information building using computer
# "hardware" nearest neighbors: software free information building using computer design
# "hardware" nearest neighbors: software free information building using computer design current
# "american" nearest neighbors: canadian
# "american" nearest neighbors: canadian german
# "american" nearest neighbors: canadian german english
# "american" nearest neighbors: canadian german english french
# "american" nearest neighbors: canadian german english french british
# "american" nearest neighbors: canadian german english french british italian
# "american" nearest neighbors: canadian german english french british italian author
# "american" nearest neighbors: canadian german english french british italian author film
# "britain" nearest neighbors: northern
# "britain" nearest neighbors: northern great
# "britain" nearest neighbors: northern great england
# "britain" nearest neighbors: northern great england country
# "britain" nearest neighbors: northern great england country along
# "britain" nearest neighbors: northern great england country along france
# "britain" nearest neighbors: northern great england country along france government
# "britain" nearest neighbors: northern great england country along france government europe
# Step 2210000, Average Loss = 5.859318
# Step 2220000, Average Loss = 5.838483
# Step 2230000, Average Loss = 5.795220
# Step 2240000, Average Loss = 5.819814
# Step 2250000, Average Loss = 5.770585
# Step 2260000, Average Loss = 5.762588
# Step 2270000, Average Loss = 5.806811
# Step 2280000, Average Loss = 5.712869
# Step 2290000, Average Loss = 5.828200
# Step 2300000, Average Loss = 5.755219
# Step 2310000, Average Loss = 5.806276
# Step 2320000, Average Loss = 5.697569
# Step 2330000, Average Loss = 5.517050
# Step 2340000, Average Loss = 5.694434
# Step 2350000, Average Loss = 5.786160
# Step 2360000, Average Loss = 5.764073
# Step 2370000, Average Loss = 5.684353
# Step 2380000, Average Loss = 5.714607
# Step 2390000, Average Loss = 5.740133
# Step 2400000, Average Loss = 5.744644
# Evaluation...
# "five" nearest neighbors: four
# "five" nearest neighbors: four three
# "five" nearest neighbors: four three six
# "five" nearest neighbors: four three six two
# "five" nearest neighbors: four three six two seven
# "five" nearest neighbors: four three six two seven eight
# "five" nearest neighbors: four three six two seven eight zero
# "five" nearest neighbors: four three six two seven eight zero nine
# "of" nearest neighbors: the
# "of" nearest neighbors: the in
# "of" nearest neighbors: the in including
# "of" nearest neighbors: the in including and
# "of" nearest neighbors: the in including and with
# "of" nearest neighbors: the in including and with original
# "of" nearest neighbors: the in including and with original from
# "of" nearest neighbors: the in including and with original from following
# "going" nearest neighbors: eventually
# "going" nearest neighbors: eventually without
# "going" nearest neighbors: eventually without how
# "going" nearest neighbors: eventually without how good
# "going" nearest neighbors: eventually without how good then
# "going" nearest neighbors: eventually without how good then which
# "going" nearest neighbors: eventually without how good then which once
# "going" nearest neighbors: eventually without how good then which once our
# "hardware" nearest neighbors: free
# "hardware" nearest neighbors: free computer
# "hardware" nearest neighbors: free computer software
# "hardware" nearest neighbors: free computer software information
# "hardware" nearest neighbors: free computer software information system
# "hardware" nearest neighbors: free computer software information system building
# "hardware" nearest neighbors: free computer software information system building design
# "hardware" nearest neighbors: free computer software information system building design program
# "american" nearest neighbors: canadian
# "american" nearest neighbors: canadian actor
# "american" nearest neighbors: canadian actor author
# "american" nearest neighbors: canadian actor author singer
# "american" nearest neighbors: canadian actor author singer born
# "american" nearest neighbors: canadian actor author singer born british
# "american" nearest neighbors: canadian actor author singer born british german
# "american" nearest neighbors: canadian actor author singer born british german english
# "britain" nearest neighbors: northern
# "britain" nearest neighbors: northern great
# "britain" nearest neighbors: northern great france
# "britain" nearest neighbors: northern great france germany
# "britain" nearest neighbors: northern great france germany government
# "britain" nearest neighbors: northern great france germany government england
# "britain" nearest neighbors: northern great france germany government england europe
# "britain" nearest neighbors: northern great france germany government england europe established
# Step 2410000, Average Loss = 5.665623
# Step 2420000, Average Loss = 5.718043
# Step 2430000, Average Loss = 5.712707
# Step 2440000, Average Loss = 5.714232
# Step 2450000, Average Loss = 5.755987
# Step 2460000, Average Loss = 5.673284
